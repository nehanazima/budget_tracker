# %% [markdown]
# # Building a Financial Advisor Chatbot
# **Learn to create an AI-powered financial assistant using hands-on-ai**
#
# ## What You'll Build
# A simple chatbot that acts as a "Financial Sage" - giving educational financial advice and analyzing transaction data from CSV files.
#
# ## Setup
#
# 1First install package

# %%
# Install required packages
# !pip install hands-on-ai pandas
# Out:
# Collecting hands-on-ai
#   Downloading hands_on_ai-0.2.1-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pandas in .\venv\Lib\site-packages (3.0.2)
# Requirement already satisfied: requests in .\venv\Lib\site-packages (from hands-on-ai) (2.33.1)
# Collecting typer (from hands-on-ai)
#   Downloading typer-0.24.2-py3-none-any.whl.metadata (15 kB)
# Collecting python-fasthtml (from hands-on-ai)
#   Downloading python_fasthtml-0.13.4-py3-none-any.whl.metadata (9.0 kB)
# Collecting python-docx (from hands-on-ai)
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting pymupdf (from hands-on-ai)
#   Downloading pymupdf-1.27.2.3-cp310-abi3-win_amd64.whl.metadata (24 kB)
# Collecting scikit-learn (from hands-on-ai)
#   Downloading scikit_learn-1.8.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy in .\venv\Lib\site-packages (from hands-on-ai) (2.4.4)
# Collecting instructor>=1.11.0 (from hands-on-ai)
#   Downloading instructor-1.15.1-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic>=2.0 (from hands-on-ai)
#   Downloading pydantic-2.13.3-py3-none-any.whl.metadata (108 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\venv\Lib\site-packages (from pandas) (2026.1)
# Collecting aiohttp<4.0.0,>=3.9.1 (from instructor>=1.11.0->hands-on-ai)
#   Downloading aiohttp-3.13.5-cp313-cp313-win_amd64.whl.metadata (8.4 kB)
# Collecting docstring-parser<1.0,>=0.16 (from instructor>=1.11.0->hands-on-ai)
#   Downloading docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in .\venv\Lib\site-packages (from instructor>=1.11.0->hands-on-ai) (3.1.6)
# Collecting jiter<0.14,>=0.6.1 (from instructor>=1.11.0->hands-on-ai)
#   Downloading jiter-0.13.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Collecting openai<3.0.0,>=2.0.0 (from instructor>=1.11.0->hands-on-ai)
#   Downloading openai-2.32.0-py3-none-any.whl.metadata (31 kB)
# Collecting pydantic-core<3.0.0,>=2.18.0 (from instructor>=1.11.0->hands-on-ai)
#   Downloading pydantic_core-2.46.3-cp313-cp313-win_amd64.whl.metadata (6.7 kB)
# Collecting rich<15.0.0,>=13.7.0 (from instructor>=1.11.0->hands-on-ai)
#   Downloading rich-14.3.4-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<10.0.0,>=8.2.3 (from instructor>=1.11.0->hands-on-ai)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in .\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai)
#   Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai)
#   Downloading multidict-6.7.1-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai)
#   Downloading propcache-0.4.1-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai)
#   Downloading yarl-1.23.0-cp313-cp313-win_amd64.whl.metadata (82 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in .\venv\Lib\site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.11.0->hands-on-ai) (3.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in .\venv\Lib\site-packages (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (4.13.0)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\venv\Lib\site-packages (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (0.28.1)
# Collecting sniffio (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.11 in .\venv\Lib\site-packages (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in .\venv\Lib\site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (3.11)
# Requirement already satisfied: certifi in .\venv\Lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\venv\Lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.0->hands-on-ai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.0->hands-on-ai)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\venv\Lib\site-packages (from requests->hands-on-ai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in .\venv\Lib\site-packages (from requests->hands-on-ai) (2.6.3)
# Collecting markdown-it-py>=2.2.0 (from rich<15.0.0,>=13.7.0->instructor>=1.11.0->hands-on-ai)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\venv\Lib\site-packages (from rich<15.0.0,>=13.7.0->instructor>=1.11.0->hands-on-ai) (2.20.0)
# Collecting click>=8.2.1 (from typer->hands-on-ai)
#   Downloading click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->hands-on-ai)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting annotated-doc>=0.0.2 (from typer->hands-on-ai)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: colorama in .\venv\Lib\site-packages (from click>=8.2.1->typer->hands-on-ai) (0.4.6)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.7.0->instructor>=1.11.0->hands-on-ai)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in .\venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting lxml>=3.1.0 (from python-docx->hands-on-ai)
#   Downloading lxml-6.1.0-cp313-cp313-win_amd64.whl.metadata (4.1 kB)
# Collecting fastcore>=1.12.41 (from python-fasthtml->hands-on-ai)
#   Downloading fastcore-1.12.43-py3-none-any.whl.metadata (3.4 kB)
# Collecting starlette~=1.0 (from python-fasthtml->hands-on-ai)
#   Downloading starlette-1.0.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting oauthlib (from python-fasthtml->hands-on-ai)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting itsdangerous (from python-fasthtml->hands-on-ai)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting uvicorn>=0.30 (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai)
#   Downloading uvicorn-0.46.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting fastlite>=0.1.1 (from python-fasthtml->hands-on-ai)
#   Downloading fastlite-0.2.4-py3-none-any.whl.metadata (12 kB)
# Collecting python-multipart (from python-fasthtml->hands-on-ai)
#   Downloading python_multipart-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: beautifulsoup4 in .\venv\Lib\site-packages (from python-fasthtml->hands-on-ai) (4.14.3)
# Collecting apswutils>=0.1.2 (from fastlite>=0.1.1->python-fasthtml->hands-on-ai)
#   Downloading apswutils-0.1.2-py3-none-any.whl.metadata (9.1 kB)
# Collecting apsw (from apswutils>=0.1.2->fastlite>=0.1.1->python-fasthtml->hands-on-ai)
#   Downloading apsw-3.53.0.0-cp313-cp313-win_amd64.whl.metadata (4.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai)
#   Downloading httptools-0.7.1-cp313-cp313-win_amd64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: pyyaml>=5.1 in .\venv\Lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (6.0.3)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai)
#   Downloading watchfiles-1.1.1-cp313-cp313-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai)
#   Downloading websockets-16.0-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in .\venv\Lib\site-packages (from beautifulsoup4->python-fasthtml->hands-on-ai) (2.8.3)
# Collecting scipy>=1.10.0 (from scikit-learn->hands-on-ai)
#   Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn->hands-on-ai)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn->hands-on-ai)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading hands_on_ai-0.2.1-py3-none-any.whl (143 kB)
# Downloading instructor-1.15.1-py3-none-any.whl (178 kB)
# Downloading aiohttp-3.13.5-cp313-cp313-win_amd64.whl (458 kB)
# Downloading docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Downloading jiter-0.13.0-cp313-cp313-win_amd64.whl (202 kB)
# Downloading multidict-6.7.1-cp313-cp313-win_amd64.whl (45 kB)
# Downloading openai-2.32.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    --------------------------- ------------ 0.8/1.2 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 4.5 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading pydantic-2.13.3-py3-none-any.whl (471 kB)
# Downloading pydantic_core-2.46.3-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------------- ------------------- 1.0/2.1 MB 5.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.1 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.7 MB/s  0:00:00
# Downloading rich-14.3.4-py3-none-any.whl (310 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading typer-0.24.2-py3-none-any.whl (55 kB)
# Downloading yarl-1.23.0-cp313-cp313-win_amd64.whl (87 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading click-8.3.3-py3-none-any.whl (110 kB)
# Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl (43 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading propcache-0.4.1-cp313-cp313-win_amd64.whl (40 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading pymupdf-1.27.2.3-cp310-abi3-win_amd64.whl (19.2 MB)
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/19.2 MB 5.7 MB/s eta 0:00:04
#    --- ------------------------------------ 1.8/19.2 MB 5.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.6/19.2 MB 4.7 MB/s eta 0:00:04
#    ------ --------------------------------- 3.1/19.2 MB 4.1 MB/s eta 0:00:04
#    ------- -------------------------------- 3.7/19.2 MB 3.7 MB/s eta 0:00:05
#    -------- ------------------------------- 4.2/19.2 MB 3.5 MB/s eta 0:00:05
#    --------- ------------------------------ 4.7/19.2 MB 3.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 5.2/19.2 MB 3.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 5.8/19.2 MB 3.1 MB/s eta 0:00:05
#    ------------- -------------------------- 6.3/19.2 MB 3.0 MB/s eta 0:00:05
#    -------------- ------------------------- 6.8/19.2 MB 3.0 MB/s eta 0:00:05
#    --------------- ------------------------ 7.6/19.2 MB 3.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 8.1/19.2 MB 3.1 MB/s eta 0:00:04
#    ------------------ --------------------- 8.9/19.2 MB 3.0 MB/s eta 0:00:04
#    ------------------- -------------------- 9.4/19.2 MB 3.0 MB/s eta 0:00:04
#    -------------------- ------------------- 9.7/19.2 MB 2.9 MB/s eta 0:00:04
#    --------------------- ------------------ 10.2/19.2 MB 2.9 MB/s eta 0:00:04
#    ---------------------- ----------------- 10.7/19.2 MB 2.9 MB/s eta 0:00:03
#    ----------------------- ---------------- 11.5/19.2 MB 2.9 MB/s eta 0:00:03
#    ------------------------- -------------- 12.1/19.2 MB 2.9 MB/s eta 0:00:03
#    -------------------------- ------------- 12.6/19.2 MB 2.9 MB/s eta 0:00:03
#    --------------------------- ------------ 13.1/19.2 MB 2.9 MB/s eta 0:00:03
#    ---------------------------- ----------- 13.6/19.2 MB 2.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 14.4/19.2 MB 2.8 MB/s eta 0:00:02
#    ------------------------------- -------- 14.9/19.2 MB 2.8 MB/s eta 0:00:02
#    -------------------------------- ------- 15.5/19.2 MB 2.8 MB/s eta 0:00:02
#    --------------------------------- ------ 16.0/19.2 MB 2.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.5/19.2 MB 2.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.3/19.2 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------- -- 17.8/19.2 MB 2.8 MB/s eta 0:00:01
#    -------------------------------------- - 18.4/19.2 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  18.9/19.2 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 19.2/19.2 MB 2.8 MB/s  0:00:06
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
# Downloading lxml-6.1.0-cp313-cp313-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.0 MB 3.4 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/4.0 MB 3.3 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.4/4.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 3.2 MB/s  0:00:01
# Downloading python_fasthtml-0.13.4-py3-none-any.whl (76 kB)
# Downloading starlette-1.0.0-py3-none-any.whl (72 kB)
# Downloading fastcore-1.12.43-py3-none-any.whl (104 kB)
# Downloading fastlite-0.2.4-py3-none-any.whl (17 kB)
# Downloading apswutils-0.1.2-py3-none-any.whl (48 kB)
# Downloading uvicorn-0.46.0-py3-none-any.whl (70 kB)
# Downloading httptools-0.7.1-cp313-cp313-win_amd64.whl (85 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading watchfiles-1.1.1-cp313-cp313-win_amd64.whl (288 kB)
# Downloading websockets-16.0-cp313-cp313-win_amd64.whl (178 kB)
# Downloading apsw-3.53.0.0-cp313-cp313-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ------------- -------------------------- 1.0/3.2 MB 4.9 MB/s eta 0:00:01
#    -------------------------- ------------- 2.1/3.2 MB 5.0 MB/s eta 0:00:01
#    -------------------------- ------------- 2.1/3.2 MB 5.0 MB/s eta 0:00:01
#    -------------------------- ------------- 2.1/3.2 MB 5.0 MB/s eta 0:00:01
#    -------------------------- ------------- 2.1/3.2 MB 5.0 MB/s eta 0:00:01
#    -------------------------------- ------- 2.6/3.2 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 2.1 MB/s  0:00:01
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading python_multipart-0.0.26-py3-none-any.whl (28 kB)
# Downloading scikit_learn-1.8.0-cp313-cp313-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.0 MB 4.6 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/8.0 MB 4.4 MB/s eta 0:00:02
#    ------------- -------------------------- 2.6/8.0 MB 4.5 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/8.0 MB 4.4 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.0 MB 4.2 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.0 MB 4.0 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.0 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/8.0 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/8.0 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 3.5 MB/s  0:00:02
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    - -------------------------------------- 1.0/36.5 MB 4.9 MB/s eta 0:00:08
#    - -------------------------------------- 1.3/36.5 MB 4.4 MB/s eta 0:00:08
#    -- ------------------------------------- 2.1/36.5 MB 3.6 MB/s eta 0:00:10
#    --- ------------------------------------ 2.9/36.5 MB 3.4 MB/s eta 0:00:10
#    --- ------------------------------------ 3.4/36.5 MB 3.2 MB/s eta 0:00:11
#    ---- ----------------------------------- 3.9/36.5 MB 3.1 MB/s eta 0:00:11
#    ---- ----------------------------------- 4.5/36.5 MB 3.1 MB/s eta 0:00:11
#    ----- ---------------------------------- 5.2/36.5 MB 3.1 MB/s eta 0:00:11
#    ------ --------------------------------- 6.0/36.5 MB 3.1 MB/s eta 0:00:10
#    ------- -------------------------------- 6.6/36.5 MB 3.1 MB/s eta 0:00:10
#    -------- ------------------------------- 7.3/36.5 MB 3.1 MB/s eta 0:00:10
#    -------- ------------------------------- 7.9/36.5 MB 3.1 MB/s eta 0:00:10
#    --------- ------------------------------ 8.7/36.5 MB 3.1 MB/s eta 0:00:09
#    ---------- ----------------------------- 9.2/36.5 MB 3.1 MB/s eta 0:00:09
#    ---------- ----------------------------- 9.7/36.5 MB 3.0 MB/s eta 0:00:09
#    ----------- ---------------------------- 10.2/36.5 MB 3.0 MB/s eta 0:00:09
#    ------------ --------------------------- 11.0/36.5 MB 3.0 MB/s eta 0:00:09
#    ------------ --------------------------- 11.5/36.5 MB 3.0 MB/s eta 0:00:09
#    ------------- -------------------------- 12.3/36.5 MB 3.1 MB/s eta 0:00:08
#    -------------- ------------------------- 12.8/36.5 MB 3.1 MB/s eta 0:00:08
#    -------------- ------------------------- 13.6/36.5 MB 3.1 MB/s eta 0:00:08
#    --------------- ------------------------ 14.2/36.5 MB 3.1 MB/s eta 0:00:08
#    ---------------- ----------------------- 14.9/36.5 MB 3.1 MB/s eta 0:00:08
#    ----------------- ---------------------- 15.7/36.5 MB 3.1 MB/s eta 0:00:07
#    ----------------- ---------------------- 16.3/36.5 MB 3.1 MB/s eta 0:00:07
#    ------------------ --------------------- 16.8/36.5 MB 3.1 MB/s eta 0:00:07
#    ------------------- -------------------- 17.6/36.5 MB 3.1 MB/s eta 0:00:07
#    ------------------- -------------------- 18.1/36.5 MB 3.1 MB/s eta 0:00:07
#    -------------------- ------------------- 18.9/36.5 MB 3.1 MB/s eta 0:00:06
#    --------------------- ------------------ 19.4/36.5 MB 3.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 20.2/36.5 MB 3.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 20.7/36.5 MB 3.1 MB/s eta 0:00:06
#    ----------------------- ---------------- 21.5/36.5 MB 3.1 MB/s eta 0:00:05
#    ------------------------ --------------- 22.0/36.5 MB 3.1 MB/s eta 0:00:05
#    ------------------------ --------------- 22.8/36.5 MB 3.1 MB/s eta 0:00:05
#    ------------------------- -------------- 23.3/36.5 MB 3.1 MB/s eta 0:00:05
#    -------------------------- ------------- 23.9/36.5 MB 3.1 MB/s eta 0:00:05
#    -------------------------- ------------- 24.1/36.5 MB 3.0 MB/s eta 0:00:05
#    -------------------------- ------------- 24.6/36.5 MB 3.0 MB/s eta 0:00:04
#    --------------------------- ------------ 24.9/36.5 MB 2.9 MB/s eta 0:00:04
#    --------------------------- ------------ 25.4/36.5 MB 2.9 MB/s eta 0:00:04
#    ---------------------------- ----------- 26.2/36.5 MB 2.9 MB/s eta 0:00:04
#    ----------------------------- ---------- 26.7/36.5 MB 2.9 MB/s eta 0:00:04
#    ------------------------------ --------- 27.5/36.5 MB 3.0 MB/s eta 0:00:04
#    ------------------------------- -------- 28.3/36.5 MB 3.0 MB/s eta 0:00:03
#    ------------------------------- -------- 28.8/36.5 MB 3.0 MB/s eta 0:00:03
#    -------------------------------- ------- 29.6/36.5 MB 3.0 MB/s eta 0:00:03
#    --------------------------------- ------ 30.1/36.5 MB 3.0 MB/s eta 0:00:03
#    --------------------------------- ------ 30.4/36.5 MB 3.0 MB/s eta 0:00:03
#    ---------------------------------- ----- 31.2/36.5 MB 3.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 32.0/36.5 MB 3.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 32.5/36.5 MB 3.0 MB/s eta 0:00:02
#    ------------------------------------ --- 33.3/36.5 MB 3.0 MB/s eta 0:00:02
#    ------------------------------------- -- 33.8/36.5 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 34.6/36.5 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 35.4/36.5 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  35.9/36.5 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.5 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 36.5/36.5 MB 2.9 MB/s  0:00:12
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: websockets, typing-inspection, tqdm, threadpoolctl, tenacity, sniffio, shellingham, scipy, python-multipart, python-dotenv, pymupdf, pydantic-core, propcache, oauthlib, multidict, mdurl, lxml, joblib, jiter, itsdangerous, httptools, frozenlist, fastcore, docstring-parser, distro, click, apsw, annotated-types, annotated-doc, aiohappyeyeballs, yarl, watchfiles, uvicorn, starlette, scikit-learn, python-docx, pydantic, markdown-it-py, apswutils, aiosignal, rich, openai, fastlite, aiohttp, typer, python-fasthtml, instructor, hands-on-ai
#
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#     ---------------------------------------  1/48 [typing-inspection]
#     ---------------------------------------  1/48 [typing-inspection]
#    - --------------------------------------  2/48 [tqdm]
#    - --------------------------------------  2/48 [tqdm]
#    - --------------------------------------  2/48 [tqdm]
#    - --------------------------------------  2/48 [tqdm]
#    - --------------------------------------  2/48 [tqdm]
#    - --------------------------------------  2/48 [tqdm]
#    - --------------------------------------  2/48 [tqdm]
#    - --------------------------------------  2/48 [tqdm]
#    - --------------------------------------  2/48 [tqdm]
#    -- -------------------------------------  3/48 [threadpoolctl]
#    --- ------------------------------------  4/48 [tenacity]
#    --- ------------------------------------  4/48 [tenacity]
#    --- ------------------------------------  4/48 [tenacity]
#    --- ------------------------------------  4/48 [tenacity]
#    ---- -----------------------------------  5/48 [sniffio]
#    ----- ----------------------------------  6/48 [shellingham]
#    ----- ----------------------------------  6/48 [shellingham]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ------ ---------------------------------  8/48 [python-multipart]
#    ------ ---------------------------------  8/48 [python-multipart]
#    ------- --------------------------------  9/48 [python-dotenv]
#    ------- --------------------------------  9/48 [python-dotenv]
#    ------- --------------------------------  9/48 [python-dotenv]
#    ------- --------------------------------  9/48 [python-dotenv]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    --------- ------------------------------ 11/48 [pydantic-core]
#    --------- ------------------------------ 11/48 [pydantic-core]
#    ---------- ----------------------------- 12/48 [propcache]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ----------- ---------------------------- 14/48 [multidict]
#    ------------ --------------------------- 15/48 [mdurl]
#    ------------- -------------------------- 16/48 [lxml]
#    ------------- -------------------------- 16/48 [lxml]
#    ------------- -------------------------- 16/48 [lxml]
#    ------------- -------------------------- 16/48 [lxml]
#    ------------- -------------------------- 16/48 [lxml]
#    ------------- -------------------------- 16/48 [lxml]
#    ------------- -------------------------- 16/48 [lxml]
#    ------------- -------------------------- 16/48 [lxml]
#    ------------- -------------------------- 16/48 [lxml]
#    ------------- -------------------------- 16/48 [lxml]
#    ------------- -------------------------- 16/48 [lxml]
#    -------------- ------------------------- 17/48 [joblib]
#    -------------- ------------------------- 17/48 [joblib]
#    -------------- ------------------------- 17/48 [joblib]
#    -------------- ------------------------- 17/48 [joblib]
# ...
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ----------------------------------- ---- 42/48 [fastlite]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ------------------------------------ --- 44/48 [typer]
#    ------------------------------------ --- 44/48 [typer]
#    ------------------------------------ --- 44/48 [typer]
#    ------------------------------------ --- 44/48 [typer]
#    ------------------------------------ --- 44/48 [typer]
#    ------------------------------------ --- 44/48 [typer]
#    ------------------------------------ --- 44/48 [typer]
#    ------------------------------------- -- 45/48 [python-fasthtml]
#    ------------------------------------- -- 45/48 [python-fasthtml]
#    ------------------------------------- -- 45/48 [python-fasthtml]
#    ------------------------------------- -- 45/48 [python-fasthtml]
#    ------------------------------------- -- 45/48 [python-fasthtml]
#    ------------------------------------- -- 45/48 [python-fasthtml]
#    ------------------------------------- -- 45/48 [python-fasthtml]
#    ------------------------------------- -- 45/48 [python-fasthtml]
#    ------------------------------------- -- 45/48 [python-fasthtml]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------- 48/48 [hands-on-ai]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 annotated-doc-0.0.4 annotated-types-0.7.0 apsw-3.53.0.0 apswutils-0.1.2 click-8.3.3 distro-1.9.0 docstring-parser-0.18.0 fastcore-1.12.43 fastlite-0.2.4 frozenlist-1.8.0 hands-on-ai-0.2.1 httptools-0.7.1 instructor-1.15.1 itsdangerous-2.2.0 jiter-0.13.0 joblib-1.5.3 lxml-6.1.0 markdown-it-py-4.0.0 mdurl-0.1.2 multidict-6.7.1 oauthlib-3.3.1 openai-2.32.0 propcache-0.4.1 pydantic-2.13.3 pydantic-core-2.46.3 pymupdf-1.27.2.3 python-docx-1.2.0 python-dotenv-1.2.2 python-fasthtml-0.13.4 python-multipart-0.0.26 rich-14.3.4 scikit-learn-1.8.0 scipy-1.17.1 shellingham-1.5.4 sniffio-1.3.1 starlette-1.0.0 tenacity-9.1.4 threadpoolctl-3.6.0 tqdm-4.67.3 typer-0.24.2 typing-inspection-0.4.2 uvicorn-0.46.0 watchfiles-1.1.1 websockets-16.0 yarl-1.23.0

# %% [markdown]
# Now lets setup environment
#
# The next few cells prepares your computer to talk to an AI service.
#
# It stores the server address, model name, and your secret key as environment variables.
#
# Other programs (or later Python code) can read those variables to connect to the AI—without hard-coding secrets into the source file.
#
# That's it! It's mainly about safe configuration: setting values once, keeping your API key private, and letting other code reuse those settings.

# %%
import os
from getpass import getpass

# %% [markdown]
# > os is a built-in Python module that lets you interact with your computer’s operating system.  In this script, it’s used to set environment variables—special settings your program (and other programs) can read.
#
# > getpass is a function that asks the user to type something (like a password) without showing it on the screen, so it stays secret.

# %%
# Configure hands-on-ai server connection
os.environ['HANDS_ON_AI_SERVER'] = 'https://ollama.locollm.org/api/generate'
os.environ['HANDS_ON_AI_MODEL'] = 'gemma3:4b'  # Quantised model on shared server

# %% [markdown]
# os.environ is like a dictionary of key-value pairs that represent environment variables.
#
# Here we create three variables:
#
# * HANDS_ON_AI_SERVER: The web address of the AI server we’ll connect to.
# * HANDS_ON_AI_MODEL: The specific AI model name we want to use (granite3.2).
# * the third is discussed later
#
# These settings can be read later by other Python code or by external tools—so you don’t have to hard-code them everywhere.

# %%
os.environ['HANDS_ON_AI_API_KEY'] = 'Curtin2026ISYS20015002'  # Shared class key

# %% [markdown]
# The cell prompts you with the message “Enter your API key: ”.
#
# The api key needed:   **isys2001-assignment-key**
#
# While you type, nothing appears on the screen (for security).
#
# Whatever you type is saved as the environment variable HANDS_ON_AI_API_KEY.
#
# > API key = a private password-like token that proves you’re allowed to use the AI service.

# %%
print("🔑 Hands-on-AI configured successfully!")
# Out:
# 🔑 Hands-on-AI configured successfully!

# %% [markdown]
# Finally, a simple confirmation message shows that the setup is done.
#
# Now lets test the package.

# %%
# Test the API directly using requests
import requests
import json

def call_ollama(prompt: str) -> str:
    """Call the Ollama server directly via REST API"""
    response = requests.post(
        'https://ollama.locollm.org/api/generate',
        headers={
            'Authorization': f"Bearer {os.environ.get('HANDS_ON_AI_API_KEY')}",
            'Content-Type': 'application/json'
        },
        json={
            'model': os.environ.get('HANDS_ON_AI_MODEL'),
            'prompt': prompt,
            'stream': False
        }
    )
    
    if response.status_code == 200:
        return response.json()['response']
    else:
        return f"Error: {response.status_code} {response.text}"

# Test it
test_response = call_ollama("What is photosynthesis?")
print("AI Response:")
print(test_response)
# Out:
# AI Response:
# Okay, let's break down photosynthesis – it's a truly amazing and fundamental process! Here's a comprehensive explanation:
#
# **What is Photosynthesis?**
#
# Photosynthesis is the process by which plants, algae, and some bacteria use sunlight to synthesize foods from carbon dioxide and water. Essentially, it’s how these organisms create their own energy source.
#
# **Here's a more detailed breakdown:**
#
# 1. **The Basics Equation:**
#    The overall reaction can be summarized like this:
#
#    **6CO₂ + 6H₂O + Sunlight → C₆H₁₂O₆ + 6O₂**
#
#    * **6CO₂:** Six molecules of Carbon Dioxide (taken from the air)
#    * **6H₂O:** Six molecules of Water (absorbed from the soil)
#    * **Sunlight:** The energy source that drives the reaction
#    * **C₆H₁₂O₆:** One molecule of Glucose (a simple sugar – the plant’s food)
#    * **6O₂:** Six molecules of Oxygen (released into the atmosphere)
#
#
# 2. **Where it Happens – The Chloroplast:**
#    Photosynthesis takes place inside specialized structures within plant cells called **chloroplasts**. These chloroplasts contain a green pigment called **chlorophyll**.
#
# 3. **The Two Main Stages:**
#    Photosynthesis isn't a single step; it's a series of reactions that are generally divided into two stages:
#
#    * **Light-Dependent Reactions (The “Photo” Part):**
#       * These reactions occur in the thylakoid membranes within the chloroplasts.
#       * **Chlorophyll** absorbs sunlight energy.
#       * This energy is used to split water molecules (H₂O) into hydrogen ions (H⁺), electrons, and oxygen (O₂).
#       * The oxygen is released as a byproduct – *this is the oxygen we breathe!*
#       * The energy from sunlight is temporarily stored in molecules like ATP and NADPH.
#
#    * **Light-Independent Reactions (The “Synthesis” Part) – Also known as the Calvin Cycle:**
#       * These reactions occur in the stroma (the fluid-filled space) of the chloroplasts.
#       * The ATP and NADPH created in the light-dependent reactions provide the energy to convert carbon dioxide (CO₂) into glucose (C₆H₁₂O₆).  This process doesn’t directly require light.
#
#
# **In simpler terms:**
#
# Plants take in sunlight, water, and carbon dioxide.  They use the sunlight’s energy to turn these ingredients into sugar (their food) and release oxygen as a waste product.
#
# **Why is Photosynthesis Important?**
#
# * **Food Production:** It's the basis of almost all food chains on Earth – plants make their own food, and then animals eat the plants (or eat animals that ate plants).
# * **Oxygen Production:**  It’s the primary source of oxygen in our atmosphere, which is essential for the survival of most living organisms.
# * **Carbon Cycle:** It helps regulate the Earth’s climate by removing carbon dioxide from the atmosphere.
#
# ---
#
# **Resources for Further Learning:**
#
# * **NASA Kids’ Club - Photosynthesis:** [https://science.nasa.gov/kidsclub/photosynthesis/](https://science.nasa.gov/kidsclub/photosynthesis/)
# * **Khan Academy - Photosynthesis:** [https://www.khanacademy.org/science/biology/photosynthesis](https://www.khanacademy.org/science/biology/photosynthesis)
#
#
# Do you want me to delve deeper into a specific aspect of photosynthesis, such as:
#
# *   The role of chlorophyll?
# *   The details of the Calvin cycle?
# *   How different plants have adapted to different light conditions?

# %% [markdown]
# ## Step 1: Ask AI to Help Design the Chatbot
#
# Let's start by asking Colab's AI to help us think through the design. thry the following prompt.
#
# ```
# Help me design a simple financial advisor chatbot that:
# 1. Takes user questions about personal finance
# 2. Gives educational advice (not professional financial advice)
# 3. Can analyze transaction data from a CSV file
# 4. Has a personality as a "wise financial sage"
#
# What should the basic structure look like in Python?
# ```

# %% [markdown]
# ## Step 2: Create the Basic Chatbot
#
# Based on AI suggestions, let's build the core chatbot:

# %%
def financial_sage(question: str):
    """
    A personality bot that provides educational financial guidance.
    """
    personality = """
    You are a wise Financial Sage with years of experience in personal finance.
    You give educational, general advice about money management, investing, and budgeting.
    You speak in a friendly but knowledgeable tone.
    Always remind users that this is educational content, not professional financial advice.
    """

    prompt = personality + "\n\nUser question: " + question
    return call_ollama(prompt)

# Test the financial sage bot
test_question = "Should I invest in stocks or save my money in a bank account?"
advice = financial_sage(test_question)

print("Financial Sage says:")
print(advice)
# Out:
# Financial Sage says:
# Hello there! That’s a fantastic question, and one that a lot of people grapple with – it’s a cornerstone of building a good financial future. Let’s talk about it.
#
# It’s wonderful that you’re thinking about investing and not just letting your money sit passively in a bank account. The key here is understanding that **stocks and savings accounts serve very different purposes.**
#
# **Let’s start with Savings Accounts:**
#
# Savings accounts are incredibly valuable for what they do – they provide safety and liquidity. They’re great for:
#
# *   **Short-term goals:** Like a vacation you’re saving for in the next year or two, or an unexpected expense like a new appliance.
# *   **Emergency Fund:** Ideally, you should have 3-6 months’ worth of essential expenses saved in a readily accessible savings account. This acts as a financial safety net.
# *   **Preserving Capital:** They're generally very low risk, meaning you’re unlikely to lose your principal.
#
# The downside is that savings accounts typically offer very low interest rates.  In some cases, inflation could actually *erode* the purchasing power of your savings over time.
#
# **Now, let’s talk about Stocks:**
#
# Investing in stocks (shares of ownership in companies) is a way to potentially grow your money over the *long term*. Here’s the gist:
#
# *   **Potential for Higher Returns:** Historically, stocks have provided significantly higher returns than savings accounts over extended periods.
# *   **Growth Potential:** You’re betting on the success of the companies you invest in.
# *   **Risk Involved:** This is the crucial part. Stocks can fluctuate in value – they can go up *and* down. You could lose some or even all of your initial investment.
#
# **So, should you choose stocks or savings?**
#
# Here’s a general guideline:
#
# *   **Short-term goals (under 5 years):** Stick with a savings account. The risk of losing money in stocks is too high.
# *   **Long-term goals (5+ years – retirement, a big purchase):** Stocks can play a significant role.
#
# **A Balanced Approach:**
#
# Many financial advisors recommend a mix of both. A common strategy is to have a portion of your savings in a savings account (for emergencies and short-term goals) and a portion invested in stocks (for long-term growth).
#
# **Important Note:** *I must stress that this is general advice.* The best approach for *you* depends on your individual circumstances, including your risk tolerance, time horizon, and financial goals.
#
# **Resources to Learn More:**
#
# *   **Investopedia:** [https://www.investopedia.com/](https://www.investopedia.com/) - Excellent resource for learning about investing terms and strategies.
# *   **Khan Academy – Personal Finance:** [https://www.khanacademy.org/personal-finance](https://www.khanacademy.org/personal-finance) – Great free courses on budgeting and investing.
#
# **Disclaimer:** *I am an AI Chatbot and not a financial advisor. This information is for educational purposes only and should not be considered professional financial advice.  It’s always best to consult with a qualified financial advisor before making any investment decisions.*
#
# To help me give you more tailored advice, could you tell me a bit more about:
#
# *   What are you saving for? (e.g., retirement, a down payment on a house, a specific purchase?)
# *   What is your time horizon – how long do you plan to invest for?
# *   And, on a scale of 1 to 10, with 1 being very risk-averse and 10 being comfortable with high risk, where would you rate your risk tolerance?

# %% [markdown]
# ## Create Sample Transaction Data
#
# Before we test the analysis features, let's create a sample transactions.csv file with some example spending data.

# %%
import pandas as pd

# Create sample transaction data
sample_transactions = {
    'Date': ['2024-01-01', '2024-01-05', '2024-01-10', '2024-01-12', '2024-01-15', '2024-01-18', '2024-01-20', '2024-01-22', '2024-01-25'],
    'Description': ['Salary', 'Groceries Coles', 'Electricity Bill', 'Coffee Shop', 'Rent Payment', 'Movie Tickets', 'Groceries Coles', 'Petrol', 'Streaming Service'],
    'Category': ['Income', 'Food', 'Utilities', 'Food', 'Housing', 'Entertainment', 'Food', 'Transport', 'Entertainment'],
    'Amount': [3000, -45.50, -120.00, -5.50, -1200.00, -30.00, -52.30, -60.00, -15.99]
}

# Create DataFrame and save as CSV
df = pd.DataFrame(sample_transactions)
df.to_csv('transactions.csv', index=False)

print("✓ Sample transactions.csv created!")
print("\nPreview of transaction data:")
print(df)
# Out:
# ✓ Sample transactions.csv created!
#
# Preview of transaction data:
#          Date        Description       Category   Amount
# 0  2024-01-01             Salary         Income  3000.00
# 1  2024-01-05    Groceries Coles           Food   -45.50
# 2  2024-01-10   Electricity Bill      Utilities  -120.00
# 3  2024-01-12        Coffee Shop           Food    -5.50
# 4  2024-01-15       Rent Payment        Housing -1200.00
# 5  2024-01-18      Movie Tickets  Entertainment   -30.00
# 6  2024-01-20    Groceries Coles           Food   -52.30
# 7  2024-01-22             Petrol      Transport   -60.00
# 8  2024-01-25  Streaming Service  Entertainment   -15.99

# %% [markdown]
# ## Step 3: Add Transaction Analysis
#
# Let's create some sample transaction data and ask AI to help us analyze it:

# %%
# Create sample transaction data
sample_transactions = {
    'Date': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-05', '2024-01-07'],
    'Description': ['Salary', 'Grocery Store', 'Coffee Shop', 'Gas Station', 'Restaurant'],
    'Category': ['Income', 'Food', 'Food', 'Transportation', 'Food'],
    'Amount': [3000, -85.50, -4.50, -45.00, -32.75]
}

# Create DataFrame and save as CSV
df = pd.DataFrame(sample_transactions)
df.to_csv('transactions.csv', index=False)

print("Sample transactions created:")
print(df)
# Out:
# Sample transactions created:
#          Date    Description        Category   Amount
# 0  2024-01-01         Salary          Income  3000.00
# 1  2024-01-02  Grocery Store            Food   -85.50
# 2  2024-01-03    Coffee Shop            Food    -4.50
# 3  2024-01-05    Gas Station  Transportation   -45.00
# 4  2024-01-07     Restaurant            Food   -32.75

# %% [markdown]
# Now let's ask AI to help us build transaction analysis.  Try this prompt:
#
# ```
# I have transaction data with columns: Date, Description, Category, Amount
# Help me write a Python function that:
# 1. Loads the CSV with pandas
# 2. Calculates basic financial insights (income, expenses, savings rate)
# 3. Identifies spending patterns
# 4. Formats this information for an AI chatbot to discuss
#
# Show me the code structure.
# ```
#
# > Can you suggest improvement to the prompt?

# %% [markdown]
# ## Step 4: Implement Transaction Analysis
#
# Based on AI suggestions, let's add transaction analysis to our sage:

# %%
def analyse_transactions(csv_file):
    """Analyze user's transaction data"""
    # Load the data
    df = pd.read_csv(csv_file)

    # Basic calculations
    total_income = df[df['Amount'] > 0]['Amount'].sum()
    total_expenses = abs(df[df['Amount'] < 0]['Amount'].sum())
    net_savings = total_income - total_expenses
    savings_rate = (net_savings / total_income * 100) if total_income > 0 else 0

    # Spending by category
    expense_by_category = df[df['Amount'] < 0].groupby('Category')['Amount'].sum().abs()

    # Create summary for AI analysis
    summary = f"""
    Financial Summary:
    - Total Income: ${total_income:.2f}
    - Total Expenses: ${total_expenses:.2f}
    - Net Savings: ${net_savings:.2f}
    - Savings Rate: {savings_rate:.1f}%

    Spending by Category:
    {expense_by_category.to_string()}
    """

    return summary

# Test transaction analysis
transaction_summary = analyse_transactions('transactions.csv')

# Get financial advice
advice = financial_sage(f"Based on my spending, how can I save more money?  {transaction_summary}")
print(advice)
# Out:
# Okay, fantastic! Let’s take a look at your financial situation. It’s absolutely brilliant that you’re already saving 94.4% of your income – that’s a truly exceptional starting point! Seriously, that’s something to be incredibly proud of.
#
# Based on your numbers, you’re doing a *remarkable* job managing your money.  It shows you're very mindful of your spending, and that's the foundation for any financial success.
#
# Now, let’s talk about *how* to potentially save even *more*. Because your savings rate is so high, we’re not necessarily looking at drastic cuts. Instead, let’s focus on optimization and potentially exploring some small enhancements.
#
# Here's a breakdown of what I'm thinking, keeping in mind this is general educational advice:
#
# **1. Food ($122.75):** This is your biggest expense category, and it's completely understandable. Food is a necessity! However, let's look for some opportunities to save a little without sacrificing enjoyment.
#
#    *   **Meal Planning:**  Seriously consider spending just 30 minutes each week planning your meals. This can dramatically reduce impulse buys and food waste.
#    *   **Cook at Home:** Eating out is almost always more expensive than cooking at home. Even a few more meals prepared at home can make a difference.
#    *   **Shop Strategically:** Look for deals, use coupons, and consider buying in bulk (where it makes sense and you'll actually use the items before they expire).
#
# **2. Transportation ($45.00):**  This is a reasonable amount.
#
#    *   **Review Commute:** If you drive, is there any way to reduce your mileage (carpool, public transport, bike, walk)?
#    *   **Maintenance:** Ensure your vehicle is properly maintained to avoid costly repairs down the line.
#
# **Overall Thoughts & Next Steps:**
#
# Your current savings rate of 94.4% is incredibly strong. You're in a fantastic position!
#
# **Here’s what I’d suggest you do:**
#
# *   **Track Your Spending *More* Closely:**  While your summary is helpful, a more granular tracking – perhaps using an app like Mint or YNAB (You Need A Budget) – can reveal even smaller spending habits you might not have realized.  It’s amazing what you can uncover!
# *   **Set a Small Savings Goal:**  Even a small, achievable goal (like saving an extra $50 per month) can build momentum and create a positive savings habit.
# *   **Revisit Your Goals:**  Are you saving for something specific (a vacation, a down payment, retirement)?  Connecting your savings to a tangible goal can be a powerful motivator.
#
# **Important Disclaimer:** *I want to reiterate that this advice is for educational purposes only and does not constitute professional financial advice.  Your individual circumstances are unique, and it's always best to consult with a qualified financial advisor for personalized guidance.*
#
# To help me give you even more tailored suggestions, could you tell me:
#
# *   What are you currently saving for (if anything)?
# *   Are there any specific areas of your spending you'd like to explore further?

# %% [markdown]
# ## Step 5: Combine Everything - Ask Questions About Your Data
#
# Now let's ask the sage to give advice based on the transaction data:

# %%
def get_advice(csv_file, question):
    """Get advice based on transaction data and user question"""

    # Get transaction analysis
    analysis = analyse_transactions(csv_file)

    # Combine with user question
    full_prompt = f"""

    Here's the user's financial data:
    {analysis}

    User question: {question}

    Based on this financial data, provide personalized educational advice.
    """

    advice = financial_sage(full_prompt)
    return advice


# Test data-based advice
data_question = "Based on my spending, how can I save more money?"
data_advice = get_advice('transactions.csv', data_question)

print("Data-Based Financial Advice:")
print(data_advice)
# Out:
# Data-Based Financial Advice:
# Okay, let’s take a look at this fantastic financial picture you’ve put together! A 94.4% savings rate is absolutely remarkable – that’s a truly impressive foundation to build upon. Seriously, congratulations on that level of discipline! It’s wonderful to see you’re already prioritizing savings so strongly.
#
# Now, you’re asking how you can *save even more*, and that's a fantastic question. It’s great that you're looking for ways to optimize – we can always strive for improvement!
#
# Let’s break down your spending and talk about some areas where you could potentially find a little extra wiggle room.
#
# **Looking at your Spending:**
#
# It appears your biggest expense is food at $122.75. That’s a significant chunk of your budget, and it’s a really common area for people to find savings.
#
# **Here's my advice, focusing on education and exploration, not specific recommendations:**
#
# 1. **Food – Let’s Investigate:**  I’d suggest taking a really close look at your food spending.
#    * **Track Your Meals:** For a month, meticulously track *everything* you spend on food.  Be honest with yourself! This will give you a clearer picture of where the money is going – are you eating out a lot?  Are you buying pre-packaged items that are more expensive than ingredients?
#    * **Meal Planning:**  Meal planning can be a huge game-changer. When you know what you're going to eat for the week, you’re less likely to impulse buy or make expensive takeout decisions.
#    * **Cook at Home:**  Seriously, cooking at home is almost always cheaper than eating out.
#    * **Grocery Shop Strategically:** Look for sales, use coupons (digital ones are very convenient!), and consider buying in bulk for items you use frequently.
#
# 2. **Transportation - Consider Options:** $45.00 seems reasonable. However, think about your transportation habits.
#     * **Can you walk or bike for shorter distances?**
#     * **Is public transportation a viable option?**
#     * **Could you carpool?**
#
# 3. **Don't Change Everything at Once:** It's tempting to make drastic changes, but it’s far better to start with small, sustainable adjustments.
#
# 4. **Remember Your Savings Rate:** Your current savings rate is incredible. Don't lose sight of that!  Even small savings adjustments can add up dramatically over time.
#
# **Important Disclaimer:** *I want to reiterate that this is general educational advice, not personalized financial advice.* To give you truly tailored recommendations, I’d need a deeper understanding of your financial goals, risk tolerance, and lifestyle.
#
# **Resources to Explore:**
#
# *   **Budgeting Apps:** There are many great apps out there (Mint, YNAB – You Need A Budget, EveryDollar) that can help you track your spending and create a budget.
# *   **Financial Education Websites:** Websites like Investopedia and NerdWallet offer tons of free information on personal finance topics.
#
# To help me understand your situation a little better and offer even more targeted advice (though still keeping in mind this is educational content), could you tell me:
#
# *   What are your primary financial goals (e.g., saving for retirement, a down payment on a house, travel)?
# *   Are there any specific areas where you feel you could cut back without significantly impacting your lifestyle?

# %% [markdown]
# ## Step 6: Create Interactive Chat Function
#
# Let's make it easy to chat with our financial sage.  This function creates a simple “chat” with a friendly money expert. When you run it, you can type questions about your finances, ask it to analyse your spending, or type quit to stop. If you ask for an analysis, it reads your transaction file, shows a summary of where your money goes, and can give extra tips if you ask follow-up questions. For anything else, it just gives general financial advice—like a basic chatbot focused on money matters.

# %%
def chat_with_sage():
    """Interactive chat with the financial sage"""

    print("💰 Welcome to the Financial Sage! 💰")
    print("Ask me any financial question, or type 'analyse' to look at your transactions.")
    print("Type 'quit' to exit.\n")

    while True:
        user_input = input("You: ")

        if user_input.lower() == 'quit':
            print("Sage: May your finances prosper! Goodbye!")
            break
        elif user_input.lower() == 'analyse':
            # Analyze transaction data
            analysis = analyse_transactions('transactions.csv')
            print(f"Sage: Here's your financial analysis:\n{analysis}")

            follow_up = input("\nAny questions about your spending? ")
            if follow_up.strip():
                advice = get_data_advice('transactions.csv', follow_up)
                print(f"Sage: {advice}")
        else:
            # Regular financial advice
            advice = get_advice('transactions.csv', user_input)
            print(f"Sage: {advice}")

        print()  # Add spacing

# %% [markdown]
# **Lets start the chatbot**
#
# > The chat_with_sage() function starts an interactive text-based conversation with a “Financial Sage” assistant. It greets the user and then repeatedly waits for input until the user types quit, which ends the chat. If the user types analyse, it calls a helper function analyse_transactions('transactions.csv') to summarise spending data from a CSV file and displays the results. After that, it offers a follow-up question prompt; if the user enters something, it calls get_data_advice('transactions.csv', follow_up) to give personalised insights based on the transaction data. For any other message, it assumes a normal financial question and calls get_advice(user_input) to generate general advice. After each response it prints a blank line for neat spacing, effectively creating a simple loop that handles quitting, transaction analysis, and everyday finance queries.

# %%
chat_with_sage()

# %% [markdown]
# ## Step 7: Test with Different Questions
#
# Let's test our sage with various financial questions:

# %%
# Test different types of questions
test_questions = [
    "I'm 22 and just started working. How should I begin investing?",
    "What's the difference between stocks and bonds?",
    "How much should I have in an emergency fund?",
    "Is it better to pay off debt or invest?",
    "Based on my spending, should I be worried about anything?"
]

print("Testing Financial Sage with various questions:")
print("=" * 50)

for question in test_questions:
    print(f"\nQuestion: {question}")

    if "based on my spending" in question.lower():
        # Use transaction data for this question
        answer = get_advice('transactions.csv', question)
    else:
        # Regular advice
        answer = financial_sage(question)

    print(f"Sage: {answer[:200]}...")  # Show first 200 characters
    print("-" * 30)
# Out:
# Testing Financial Sage with various questions:
# ==================================================
#
# Question: I'm 22 and just started working. How should I begin investing?
# Sage: Hello there! Fantastic that you’re starting to think about investing at 22 – it’s *the* smartest move you can make! Seriously, the power of compound interest is going to be your greatest ally in the l...
# ------------------------------
#
# Question: What's the difference between stocks and bonds?
# Sage: Hello there! That’s a fantastic question – it’s one that’s absolutely crucial when you're starting to think about building a portfolio. Let’s break down the difference between stocks and bonds. They’r...
# ------------------------------
#
# Question: How much should I have in an emergency fund?
# Sage: Hello there! It's wonderful you're thinking about building a solid financial foundation. That’s a fantastic question about the emergency fund – it’s truly one of the most crucial things you can do for...
# ------------------------------
#
# Question: Is it better to pay off debt or invest?
# Sage: Hello there! That’s a fantastic question, and one that many people wrestle with. It's a really common dilemma, and honestly, there isn’t one single “right” answer. It depends entirely on *your* specif...
# ------------------------------
#
# Question: Based on my spending, should I be worried about anything?
# Sage: Okay, let’s take a look at this fantastic financial picture you’ve presented! Seriously, a 94.4% savings rate is something to be incredibly proud of – that’s a phenomenal foundation to build on. It’s ...
# ------------------------------

# %% [markdown]
# ## Step 8: Ask AI for Improvements
#
# Let's ask AI how to make our chatbot better.  Try this prompt:
#
# ```
# I built a simple financial advisor chatbot that:
# - Answers financial questions with educational advice
# - Analyzes CSV transaction data
# - Combines data analysis with personalized advice
#
# How could I improve this chatbot? What features would make it more useful?
# What are potential issues I should watch out for?
# ```

# %% [markdown]
# ## Your Turn: Extend the Chatbot
#
# Try adding one of these features with AI help:
#
# * Add budget planning capabilities
# * Include goal-setting and tracking
# * Add investment portfolio analysis
# * Create spending categorization rules
# * Add financial education tips

# %%
def my_chatbot_extension():
    import pandas as pd

    df = pd.read_csv("transactions.csv")

    income = df[df['Amount'] > 0]['Amount'].sum()
    expenses = abs(df[df['Amount'] < 0]['Amount'].sum())

    print("Total Income:", income)
    print("Total Expenses:", expenses)

    if income > 0:
        savings_rate = ((income - expenses) / income) * 100
        print(f"Savings Rate: {savings_rate:.2f}%")

my_chatbot_extension()
# Out:
# Total Income: 3000.0
# Total Expenses: 167.75
# Savings Rate: 94.41%

# %% [markdown]
# ## Key Takeaways
#
# You've built a financial advisor chatbot that:
# - Uses AI to provide educational financial advice
# - Analyzes real transaction data from CSV files
# - Combines data insights with personalized recommendations
# - Demonstrates how to use LLMs for domain-specific applications
#
# This shows how AI can be used to create helpful financial tools while maintaining appropriate disclaimers about not providing professional financial advice.
#
# ## Next Steps
#
# - Upload your own transactions.csv file and test the analysis
# - Add more sophisticated financial calculations
# - Integrate with the API and scraping tutorials
# - Build a Gradio interface for better user experience
# - Explore more advanced financial analysis features
#
# Remember: This is educational content and not professional financial advice!
